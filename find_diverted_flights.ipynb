# %%
import pandas as pd
import math

# %%
df = pd.read_csv('Dataset/Combined_Flights_2021.csv')
df
# Out:
#          FlightDate                 Airline Origin Dest  Cancelled  Diverted  \
# 0        2021-03-03   SkyWest Airlines Inc.    SGU  PHX      False     False
# 1        2021-03-03   SkyWest Airlines Inc.    PHX  SGU      False     False
# 2        2021-03-03   SkyWest Airlines Inc.    MHT  ORD      False     False
# 3        2021-03-03   SkyWest Airlines Inc.    DFW  TRI      False     False
# 4        2021-03-03   SkyWest Airlines Inc.    PHX  BFL      False     False
# ...             ...                     ...    ...  ...        ...       ...
# 6311866  2021-06-01  Southwest Airlines Co.    BNA  MDW      False     False
# 6311867  2021-06-01  Southwest Airlines Co.    BNA  MDW      False     False
# 6311868  2021-06-01  Southwest Airlines Co.    BNA  MIA      False     False
# 6311869  2021-06-01  Southwest Airlines Co.    BNA  MIA      False     False
# 6311870  2021-06-01  Southwest Airlines Co.    BNA  MKE      False     False
#
# ...

# %%
start_date = '2021-11-20'
end_date = '2021-11-30'
mask = (df['FlightDate'] >= start_date) & (df['FlightDate'] <= end_date)
df2 = df.loc[mask]
print(df2)
# Out:
#          FlightDate                      Airline Origin Dest  Cancelled  \
# 1532305  2021-11-26           Mesa Airlines Inc.    RDU  IAD      False
# 1532306  2021-11-30           Mesa Airlines Inc.    CVG  ORD      False
# 1532307  2021-11-26           Mesa Airlines Inc.    IAH  SRQ      False
# 1532308  2021-11-24           Mesa Airlines Inc.    SRQ  IAD      False
# 1532309  2021-11-22           Mesa Airlines Inc.    IAD  SRQ      False
# ...             ...                          ...    ...  ...        ...
# 2095860  2021-11-20  Air Wisconsin Airlines Corp    BUF  ORD      False
# 2095861  2021-11-20  Air Wisconsin Airlines Corp    MKE  ORD      False
# 2095862  2021-11-20  Air Wisconsin Airlines Corp    IAD  CHO      False
# 2095863  2021-11-20  Air Wisconsin Airlines Corp    COU  ORD      False
# 2095864  2021-11-20  Air Wisconsin Airlines Corp    CAE  ORD      False
#
#          Diverted  CRSDepTime  DepTime  DepDelayMinutes  DepDelay  ...  \
# ...

# %%
df2 = df2.loc[(df2['Diverted'] == True)]
df2
# Out:
#          FlightDate                                    Airline Origin Dest  \
# 1539335  2021-11-27                         Mesa Airlines Inc.    TUS  ORD
# 1539336  2021-11-27                         Mesa Airlines Inc.    IAH  DCA
# 1539337  2021-11-30                         Mesa Airlines Inc.    LGA  IAH
# 1539338  2021-11-24                         Mesa Airlines Inc.    IAH  ONT
# 1539339  2021-11-29                         Mesa Airlines Inc.    ONT  IAH
# ...             ...                                        ...    ...  ...
# 2089529  2021-11-29                Air Wisconsin Airlines Corp    ORD  AZO
# 2089675  2021-11-29                Air Wisconsin Airlines Corp    ORD  HPN
# 2090936  2021-11-27   GoJet Airlines, LLC d/b/a United Express    IAD  GRR
# 2093087  2021-11-24                Air Wisconsin Airlines Corp    COU  ORD
# 2094587  2021-11-21  Commutair Aka Champlain Enterprises, Inc.    TUL  IAH
#
# ...

# %%
count_row = df2.shape[0]
print(count_row)
# Out:
# 263
